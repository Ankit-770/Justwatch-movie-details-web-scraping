# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-770/Justwatch-movie-details-web-scraping/blob/main/justwatch_movie_%26_series_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# Name- Ankit Choudhary
#
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the assignment.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/movies?release_year_from=2000'

# Sending an HTTP GET request to the URL
page=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
responce=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(responce.prettify())

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# Write Your Code here
movie_links = []
data_dict = dict()

for i in range(1):
  url='https://www.justwatch.com/in/movies?release_year_from=2000'
  response = requests.get(url)
  tags = BeautifulSoup(response.content, "html.parser")

  links = tags.find_all("a", class_="title-list-grid__item--link")
  for link in links:
    text = link['href']
    movie_links.append('https://www.justwatch.com' + text.strip())

data_dict['link'] = movie_links
# pd.DataFrame(data_dict)

# %%
pd.DataFrame(data_dict)
# Out:
#                                                  link
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
# [100 rows x 1 columns]

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
# Write Your Code here
movie_title = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    title = tags.find("h1").text.strip()
    movie_title.append(title)

data_dict['title'] = movie_title
# pd.DataFrame(data_dict)

# %%
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title
# 0                         Animal
# 1                      12th Fail
# 2                         Salaar
# 3                    Sam Bahadur
# 4   Aquaman and the Lost Kingdom
# ..                           ...
# 95                       Pathaan
# 96                       Kannagi
# 97                 Blood Diamond
# 98       Ala Vaikunthapurramuloo
# 99              K.G.F: Chapter 2
#
# [100 rows x 2 columns]

# %% [markdown]
# ## **Scrapping release Year**

# %%
# Write Your Code here
release_year = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    years = tags.find('span', class_="text-muted").text.strip()
    release_year.append(years)

data_dict['year'] = release_year
# pd.DataFrame(data_dict)

# %%
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title    year
# 0                         Animal  (2023)
# 1                      12th Fail  (2023)
# 2                         Salaar  (2023)
# 3                    Sam Bahadur  (2023)
# 4   Aquaman and the Lost Kingdom  (2023)
# ..                           ...     ...
# 95                       Pathaan  (2023)
# 96                       Kannagi  (2023)
# 97                 Blood Diamond  (2006)
# 98       Ala Vaikunthapurramuloo  (2020)
# 99              K.G.F: Chapter 2  (2022)
#
# [100 rows x 3 columns]

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Write Your Code here
movie_genres = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    genres = tags.find('h3', class_="detail-infos__subheading", string="Genres").find_next('div', class_="detail-infos__value").text.strip()
    movie_genres.append(genres)

# pd.DataFrame(movie_genres)
# data_dict['genres'] = movie_genres
# pd.DataFrame(data_dict)

# %%
data_dict['genres'] = movie_genres
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title    year  \
# 0                         Animal  (2023)
# 1                      12th Fail  (2023)
# 2                         Salaar  (2023)
# 3                    Sam Bahadur  (2023)
# 4   Aquaman and the Lost Kingdom  (2023)
# ..                           ...     ...
# 95                       Pathaan  (2023)
# 96                       Kannagi  (2023)
# 97                 Blood Diamond  (2006)
# 98       Ala Vaikunthapurramuloo  (2020)
# 99              K.G.F: Chapter 2  (2022)
#
#                                                genres
# 0   Action & Adventure, Drama, Crime, Mystery & Th...
# 1                                               Drama
# 2   Mystery & Thriller, Action & Adventure, Crime,...
# 3                      War & Military, Drama, History
# 4        Fantasy, Action & Adventure, Science-Fiction
# ..                                                ...
# 95      Mystery & Thriller, Drama, Action & Adventure
# 96                                            Romance
# 97      Action & Adventure, Drama, Mystery & Thriller
# 98                  Comedy, Drama, Action & Adventure
# 99  Crime, Drama, Mystery & Thriller, Action & Adv...
#
# [100 rows x 4 columns]

# %% [markdown]
# ## **Scrapping IMBD Rating**

# %%
# Write Your Code here
imdb_rating = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    rating_tag = tags.find('div', class_="jw-scoring-listing__rating")
    rating = rating_tag.find_next('span').text if rating_tag else 'None'
    imdb_rating.append(rating)

#pd.DataFrame(imdb_rating)
# data_dict['genres'] = imdb_rating
# pd.DataFrame(data_dict)

# %%
data_dict['imdb_rating'] = imdb_rating
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title    year  \
# 0                         Animal  (2023)
# 1                      12th Fail  (2023)
# 2                         Salaar  (2023)
# 3                    Sam Bahadur  (2023)
# 4   Aquaman and the Lost Kingdom  (2023)
# ..                           ...     ...
# 95                       Pathaan  (2023)
# 96                       Kannagi  (2023)
# 97                 Blood Diamond  (2006)
# 98       Ala Vaikunthapurramuloo  (2020)
# 99              K.G.F: Chapter 2  (2022)
#
#                                                genres    imdb_rating  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...    6.4  (76k)
# 1                                               Drama    9.2  (93k)
# 2   Mystery & Thriller, Action & Adventure, Crime,...    6.6  (56k)
# 3                      War & Military, Drama, History    7.9  (11k)
# 4        Fantasy, Action & Adventure, Science-Fiction    5.7  (49k)
# ..                                                ...            ...
# 95      Mystery & Thriller, Drama, Action & Adventure   5.9  (155k)
# 96                                            Romance     7.8  (5k)
# 97      Action & Adventure, Drama, Mystery & Thriller   8.0  (580k)
# 98                  Comedy, Drama, Action & Adventure    7.3  (23k)
# 99  Crime, Drama, Mystery & Thriller, Action & Adv...   8.3  (148k)
#
#    movie_duration age_rating      production_country  \
# 0        3h 21min          A                   India
# 1        2h 26min       None                   India
# 2        2h 55min          A                   India
# 3        2h 30min         UA                   India
# 4         2h 4min       None           United States
# ..            ...        ...                     ...
# 95       2h 26min       None    India, United States
# 96       2h 38min         UA                   India
# 97       2h 23min          A  United States, Germany
# 98       2h 45min         UA                   India
# 99       2h 46min         UA                   India
#
#                                     streaming_service
# 0   Currently you are able to watch "Animal" strea...
# 1   Currently you are able to watch "12th Fail" st...
# 2   Currently you are able to watch "Salaar" strea...
# 3   Currently you are able to watch "Sam Bahadur" ...
# 4   You can buy "Aquaman and the Lost Kingdom" on ...
# ..                                                ...
# 95  Currently you are able to watch "Pathaan" stre...
# 96  Currently you are able to watch "Kannagi" stre...
# 97  Currently you are able to watch "Blood Diamond...
# 98  Currently you are able to watch "Ala Vaikuntha...
# 99  Currently you are able to watch "K.G.F: Chapte...
#
# [100 rows x 9 columns]

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
# Write Your Code here
movie_duration = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    duration = tags.find('h3', class_="detail-infos__subheading", string="Runtime").find_next('div', class_="detail-infos__value").text.strip()
    movie_duration.append(duration)

pd.DataFrame(movie_duration)
# data_dict['movie_duration'] = movie_duration
# pd.DataFrame(data_dict)

# %%
data_dict['movie_duration'] = movie_duration
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title    year  \
# 0                         Animal  (2023)
# 1                      12th Fail  (2023)
# 2                         Salaar  (2023)
# 3                    Sam Bahadur  (2023)
# 4   Aquaman and the Lost Kingdom  (2023)
# ..                           ...     ...
# 95                       Pathaan  (2023)
# 96                       Kannagi  (2023)
# 97                 Blood Diamond  (2006)
# 98       Ala Vaikunthapurramuloo  (2020)
# 99              K.G.F: Chapter 2  (2022)
#
#                                                genres    imdb_rating  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...    6.4  (76k)
# 1                                               Drama    9.2  (93k)
# 2   Mystery & Thriller, Action & Adventure, Crime,...    6.6  (56k)
# 3                      War & Military, Drama, History    7.9  (11k)
# 4        Fantasy, Action & Adventure, Science-Fiction    5.7  (49k)
# ..                                                ...            ...
# 95      Mystery & Thriller, Drama, Action & Adventure   5.9  (155k)
# 96                                            Romance     7.8  (5k)
# 97      Action & Adventure, Drama, Mystery & Thriller   8.0  (580k)
# 98                  Comedy, Drama, Action & Adventure    7.3  (23k)
# 99  Crime, Drama, Mystery & Thriller, Action & Adv...   8.3  (148k)
#
#    movie_duration
# 0        3h 21min
# 1        2h 26min
# 2        2h 55min
# 3        2h 30min
# 4         2h 4min
# ..            ...
# 95       2h 26min
# 96       2h 38min
# 97       2h 23min
# 98       2h 45min
# 99       2h 46min
#
# [100 rows x 6 columns]

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Write Your Code here
age_rating = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    age_tag = tags.find('h3', class_="detail-infos__subheading", string="Age rating")
    adulat_rating = age_tag.find_next('div', class_="detail-infos__value").text.strip() if age_tag else 'None'
    age_rating.append(adulat_rating)

# pd.DataFrame(age_rating)
# data_dict['age_rating'] = age_rating
# pd.DataFrame(data_dict)

# %%
data_dict['age_rating'] = age_rating
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title    year  \
# 0                         Animal  (2023)
# 1                      12th Fail  (2023)
# 2                         Salaar  (2023)
# 3                    Sam Bahadur  (2023)
# 4   Aquaman and the Lost Kingdom  (2023)
# ..                           ...     ...
# 95                       Pathaan  (2023)
# 96                       Kannagi  (2023)
# 97                 Blood Diamond  (2006)
# 98       Ala Vaikunthapurramuloo  (2020)
# 99              K.G.F: Chapter 2  (2022)
#
#                                                genres    imdb_rating  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...    6.4  (76k)
# 1                                               Drama    9.2  (93k)
# 2   Mystery & Thriller, Action & Adventure, Crime,...    6.6  (56k)
# 3                      War & Military, Drama, History    7.9  (11k)
# 4        Fantasy, Action & Adventure, Science-Fiction    5.7  (49k)
# ..                                                ...            ...
# 95      Mystery & Thriller, Drama, Action & Adventure   5.9  (155k)
# 96                                            Romance     7.8  (5k)
# 97      Action & Adventure, Drama, Mystery & Thriller   8.0  (580k)
# 98                  Comedy, Drama, Action & Adventure    7.3  (23k)
# 99  Crime, Drama, Mystery & Thriller, Action & Adv...   8.3  (148k)
#
#    movie_duration age_rating
# 0        3h 21min          A
# 1        2h 26min       None
# 2        2h 55min          A
# 3        2h 30min         UA
# 4         2h 4min       None
# ..            ...        ...
# 95       2h 26min       None
# 96       2h 38min         UA
# 97       2h 23min          A
# 98       2h 45min         UA
# 99       2h 46min         UA
#
# [100 rows x 7 columns]

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
# Write Your Code here
production_country = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    country = tags.find('h3', class_="detail-infos__subheading", string=" Production country ").find_next('div', class_="detail-infos__value").text.strip()
    production_country.append(country)

# pd.DataFrame(production_country)
# data_dict['production_country'] = production_country
# pd.DataFrame(data_dict)

# %%
data_dict['production_country'] = production_country
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title    year  \
# 0                         Animal  (2023)
# 1                      12th Fail  (2023)
# 2                         Salaar  (2023)
# 3                    Sam Bahadur  (2023)
# 4   Aquaman and the Lost Kingdom  (2023)
# ..                           ...     ...
# 95                       Pathaan  (2023)
# 96                       Kannagi  (2023)
# 97                 Blood Diamond  (2006)
# 98       Ala Vaikunthapurramuloo  (2020)
# 99              K.G.F: Chapter 2  (2022)
#
#                                                genres    imdb_rating  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...    6.4  (76k)
# 1                                               Drama    9.2  (93k)
# 2   Mystery & Thriller, Action & Adventure, Crime,...    6.6  (56k)
# 3                      War & Military, Drama, History    7.9  (11k)
# 4        Fantasy, Action & Adventure, Science-Fiction    5.7  (49k)
# ..                                                ...            ...
# 95      Mystery & Thriller, Drama, Action & Adventure   5.9  (155k)
# 96                                            Romance     7.8  (5k)
# 97      Action & Adventure, Drama, Mystery & Thriller   8.0  (580k)
# 98                  Comedy, Drama, Action & Adventure    7.3  (23k)
# 99  Crime, Drama, Mystery & Thriller, Action & Adv...   8.3  (148k)
#
#    movie_duration age_rating      production_country
# 0        3h 21min          A                   India
# 1        2h 26min       None                   India
# 2        2h 55min          A                   India
# 3        2h 30min         UA                   India
# 4         2h 4min       None           United States
# ..            ...        ...                     ...
# 95       2h 26min       None    India, United States
# 96       2h 38min         UA                   India
# 97       2h 23min          A  United States, Germany
# 98       2h 45min         UA                   India
# 99       2h 46min         UA                   India
#
# [100 rows x 8 columns]

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# Write Your Code here
streaming_service = []
for link in movie_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    platform = tags.find('h2', class_="heading").find_next('p').text.strip()
    streaming_service.append(platform)

# pd.DataFrame(streaming_service)
# data_dict['streaming_service'] = streaming_service
# pd.DataFrame(data_dict)

# %%
data_dict['streaming_service'] = streaming_service
pd.DataFrame(data_dict)
# Out:
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                            title    year  \
# 0                         Animal  (2023)
# 1                      12th Fail  (2023)
# 2                         Salaar  (2023)
# 3                    Sam Bahadur  (2023)
# 4   Aquaman and the Lost Kingdom  (2023)
# ..                           ...     ...
# 95                       Pathaan  (2023)
# 96                       Kannagi  (2023)
# 97                 Blood Diamond  (2006)
# 98       Ala Vaikunthapurramuloo  (2020)
# 99              K.G.F: Chapter 2  (2022)
#
#                                                genres    imdb_rating  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...    6.4  (76k)
# 1                                               Drama    9.2  (93k)
# 2   Mystery & Thriller, Action & Adventure, Crime,...    6.6  (56k)
# 3                      War & Military, Drama, History    7.9  (11k)
# 4        Fantasy, Action & Adventure, Science-Fiction    5.7  (49k)
# ..                                                ...            ...
# 95      Mystery & Thriller, Drama, Action & Adventure   5.9  (155k)
# 96                                            Romance     7.8  (5k)
# 97      Action & Adventure, Drama, Mystery & Thriller   8.0  (580k)
# 98                  Comedy, Drama, Action & Adventure    7.3  (23k)
# 99  Crime, Drama, Mystery & Thriller, Action & Adv...   8.3  (148k)
#
#    movie_duration age_rating      production_country  \
# 0        3h 21min          A                   India
# 1        2h 26min       None                   India
# 2        2h 55min          A                   India
# 3        2h 30min         UA                   India
# 4         2h 4min       None           United States
# ..            ...        ...                     ...
# 95       2h 26min       None    India, United States
# 96       2h 38min         UA                   India
# 97       2h 23min          A  United States, Germany
# 98       2h 45min         UA                   India
# 99       2h 46min         UA                   India
#
#                                     streaming_service
# 0   Currently you are able to watch "Animal" strea...
# 1   Currently you are able to watch "12th Fail" st...
# 2   Currently you are able to watch "Salaar" strea...
# 3   Currently you are able to watch "Sam Bahadur" ...
# 4   You can buy "Aquaman and the Lost Kingdom" on ...
# ..                                                ...
# 95  Currently you are able to watch "Pathaan" stre...
# 96  Currently you are able to watch "Kannagi" stre...
# 97  Currently you are able to watch "Blood Diamond...
# 98  Currently you are able to watch "Ala Vaikuntha...
# 99  Currently you are able to watch "K.G.F: Chapte...
#
# [100 rows x 9 columns]

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# Write Your Code here
pd.DataFrame(data_dict, columns=['title', 'year', 'movie_duration', 'imdb_rating', 'age_rating', 'production_country', 'genres', 'link', 'streaming_service'])
# Out:
#                            title    year movie_duration    imdb_rating  \
# 0                         Animal  (2023)       3h 21min    6.4  (76k)
# 1                      12th Fail  (2023)       2h 26min    9.2  (93k)
# 2                         Salaar  (2023)       2h 55min    6.6  (56k)
# 3                    Sam Bahadur  (2023)       2h 30min    7.9  (11k)
# 4   Aquaman and the Lost Kingdom  (2023)        2h 4min    5.7  (49k)
# ..                           ...     ...            ...            ...
# 95                       Pathaan  (2023)       2h 26min   5.9  (155k)
# 96                       Kannagi  (2023)       2h 38min     7.8  (5k)
# 97                 Blood Diamond  (2006)       2h 23min   8.0  (580k)
# 98       Ala Vaikunthapurramuloo  (2020)       2h 45min    7.3  (23k)
# 99              K.G.F: Chapter 2  (2022)       2h 46min   8.3  (148k)
#
#    age_rating      production_country  \
# 0           A                   India
# 1        None                   India
# 2           A                   India
# 3          UA                   India
# 4        None           United States
# ..        ...                     ...
# 95       None    India, United States
# 96         UA                   India
# 97          A  United States, Germany
# 98         UA                   India
# 99         UA                   India
#
#                                                genres  \
# 0   Action & Adventure, Drama, Crime, Mystery & Th...
# 1                                               Drama
# 2   Mystery & Thriller, Action & Adventure, Crime,...
# 3                      War & Military, Drama, History
# 4        Fantasy, Action & Adventure, Science-Fiction
# ..                                                ...
# 95      Mystery & Thriller, Drama, Action & Adventure
# 96                                            Romance
# 97      Action & Adventure, Drama, Mystery & Thriller
# 98                  Comedy, Drama, Action & Adventure
# 99  Crime, Drama, Mystery & Thriller, Action & Adv...
#
#                                                  link  \
# 0      https://www.justwatch.com/in/movie/animal-2022
# 1        https://www.justwatch.com/in/movie/12th-fail
# 2           https://www.justwatch.com/in/movie/salaar
# 3      https://www.justwatch.com/in/movie/sam-bahadur
# 4   https://www.justwatch.com/in/movie/aquaman-and...
# ..                                                ...
# 95         https://www.justwatch.com/in/movie/pathaan
# 96         https://www.justwatch.com/in/movie/kannagi
# 97   https://www.justwatch.com/in/movie/blood-diamond
# 98  https://www.justwatch.com/in/movie/ala-vaikunt...
# 99  https://www.justwatch.com/in/movie/k-g-f-chapt...
#
#                                     streaming_service
# 0   Currently you are able to watch "Animal" strea...
# 1   Currently you are able to watch "12th Fail" st...
# 2   Currently you are able to watch "Salaar" strea...
# 3   Currently you are able to watch "Sam Bahadur" ...
# 4   You can buy "Aquaman and the Lost Kingdom" on ...
# ..                                                ...
# 95  Currently you are able to watch "Pathaan" stre...
# 96  Currently you are able to watch "Kannagi" stre...
# 97  Currently you are able to watch "Blood Diamond...
# 98  Currently you are able to watch "Ala Vaikuntha...
# 99  Currently you are able to watch "K.G.F: Chapte...
#
# [100 rows x 9 columns]

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
# Sending an HTTP GET request to the URL
page=requests.get(tv_url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
responce=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(responce.prettify())

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Write Your Code here
tv_show_links = []
tv_dict = dict()

for i in range(1):
  tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
  response = requests.get(tv_url)
  tags = BeautifulSoup(response.content, "html.parser")

  links = tags.find_all("a", class_="title-list-grid__item--link")
  for link in links:
    text = link['href']
    tv_show_links.append('https://www.justwatch.com' + text.strip())

tv_dict['link'] = tv_show_links
# pd.DataFrame(tv_dict)

# %%
pd.DataFrame(tv_dict)
# Out:
#                                                  link
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
# [100 rows x 1 columns]

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Write Your Code here
tvshow_title = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    title = tags.find("h1").text.strip()
    tvshow_title.append(title)

# pd.DataFrame(tvshow_title)
# tv_dict['title'] = tvshow_title
# pd.DataFrame(tv_dict)

# %%
tv_dict['title'] = tvshow_title
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title
# 0                          Reacher
# 1                   True Detective
# 2              Indian Police Force
# 3                         Mirzapur
# 4                  Game of Thrones
# ..                             ...
# 95             The Big Bang Theory
# 96                       The Flash
# 97  Alexander: The Making of a God
# 98       The King: Eternal Monarch
# 99      The Trust: A Game of Greed
#
# [100 rows x 2 columns]

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Write Your Code here
release_year = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    year = tags.find('span', class_="text-muted").text.strip()
    release_year.append(year)

# pd.DataFrame(release_year)
# tv_dict['release_year'] = release_year
# pd.DataFrame(tv_dict)

# %%
tv_dict['release_year'] = release_year
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title release_year
# 0                          Reacher       (2022)
# 1                   True Detective       (2014)
# 2              Indian Police Force       (2024)
# 3                         Mirzapur       (2018)
# 4                  Game of Thrones       (2011)
# ..                             ...          ...
# 95             The Big Bang Theory       (2007)
# 96                       The Flash       (2014)
# 97  Alexander: The Making of a God       (2024)
# 98       The King: Eternal Monarch       (2020)
# 99      The Trust: A Game of Greed       (2024)
#
# [100 rows x 3 columns]

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Write Your Code here
tvshow_genre = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    genre = tags.find('h3', class_="detail-infos__subheading", string="Genres").find_next('div', class_="detail-infos__value").text.strip()
    tvshow_genre.append(genre)

# pd.DataFrame(tvshow_genre)
# tv_dict['genre'] = tvshow_genre
# pd.DataFrame(tv_dict)

# %%
tv_dict['genre'] = tvshow_genre
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title release_year  \
# 0                          Reacher       (2022)
# 1                   True Detective       (2014)
# 2              Indian Police Force       (2024)
# 3                         Mirzapur       (2018)
# 4                  Game of Thrones       (2011)
# ..                             ...          ...
# 95             The Big Bang Theory       (2007)
# 96                       The Flash       (2014)
# 97  Alexander: The Making of a God       (2024)
# 98       The King: Eternal Monarch       (2020)
# 99      The Trust: A Game of Greed       (2024)
#
#                                                 genre
# 0   Action & Adventure, Crime, Drama, Mystery & Th...
# 1                    Drama, Mystery & Thriller, Crime
# 2                           Action & Adventure, Crime
# 3   Crime, Action & Adventure, Drama, Mystery & Th...
# 4   Drama, Action & Adventure, Science-Fiction, Fa...
# ..                                                ...
# 95                                    Comedy, Romance
# 96         Action & Adventure, Drama, Science-Fiction
# 97                        Documentary, Drama, History
# 98                             Drama, Science-Fiction
# 99                                         Reality TV
#
# [100 rows x 4 columns]

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Write Your Code here
imdb_rating = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    rating_tag = tags.find('div', class_="jw-scoring-listing__rating")
    rating = rating_tag.find_next('span').text.strip() if rating_tag else 'None'
    imdb_rating.append(rating)

# pd.DataFrame(imdb_rating)
# tv_dict['imdb_rating'] = imdb_rating
# pd.DataFrame(tv_dict)

# %%
tv_dict['imdb_rating'] = imdb_rating
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title release_year  \
# 0                          Reacher       (2022)
# 1                   True Detective       (2014)
# 2              Indian Police Force       (2024)
# 3                         Mirzapur       (2018)
# 4                  Game of Thrones       (2011)
# ..                             ...          ...
# 95             The Big Bang Theory       (2007)
# 96                       The Flash       (2014)
# 97  Alexander: The Making of a God       (2024)
# 98       The King: Eternal Monarch       (2020)
# 99      The Trust: A Game of Greed       (2024)
#
#                                                 genre     imdb_rating
# 0   Action & Adventure, Crime, Drama, Mystery & Th...     8.1  (195k)
# 1                    Drama, Mystery & Thriller, Crime     8.9  (632k)
# 2                           Action & Adventure, Crime      5.8  (50k)
# 3   Crime, Action & Adventure, Drama, Mystery & Th...      8.5  (80k)
# 4   Drama, Action & Adventure, Science-Fiction, Fa...       9.2  (2m)
# ..                                                ...             ...
# 95                                    Comedy, Romance     8.2  (857k)
# 96         Action & Adventure, Drama, Science-Fiction     7.5  (366k)
# 97                        Documentary, Drama, History       5.1  (2k)
# 98                             Drama, Science-Fiction  Baek Sang-Hoon
# 99                                         Reality TV             6.2
#
# [100 rows x 5 columns]

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Write Your Code here
age_rating = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    age_tag = tags.find('h3', class_="detail-infos__subheading", string="Age rating")
    adulat_rating = age_tag.find_next('div', class_="detail-infos__value").text.strip() if age_tag else 'None'
    age_rating.append(adulat_rating)

# pd.DataFrame(age_rating)
# tv_dict['age_rating'] = age_rating
# pd.DataFrame(tv_dict)

# %%
tv_dict['age_rating'] = age_rating
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title release_year  \
# 0                          Reacher       (2022)
# 1                   True Detective       (2014)
# 2              Indian Police Force       (2024)
# 3                         Mirzapur       (2018)
# 4                  Game of Thrones       (2011)
# ..                             ...          ...
# 95             The Big Bang Theory       (2007)
# 96                       The Flash       (2014)
# 97  Alexander: The Making of a God       (2024)
# 98       The King: Eternal Monarch       (2020)
# 99      The Trust: A Game of Greed       (2024)
#
#                                                 genre     imdb_rating  \
# 0   Action & Adventure, Crime, Drama, Mystery & Th...     8.1  (195k)
# 1                    Drama, Mystery & Thriller, Crime     8.9  (632k)
# 2                           Action & Adventure, Crime      5.8  (50k)
# 3   Crime, Action & Adventure, Drama, Mystery & Th...      8.5  (80k)
# 4   Drama, Action & Adventure, Science-Fiction, Fa...       9.2  (2m)
# ..                                                ...             ...
# 95                                    Comedy, Romance     8.2  (857k)
# 96         Action & Adventure, Drama, Science-Fiction     7.5  (366k)
# 97                        Documentary, Drama, History       5.1  (2k)
# 98                             Drama, Science-Fiction  Baek Sang-Hoon
# 99                                         Reality TV             6.2
#
#    age_rating
# 0           A
# 1           U
# 2           A
# 3        None
# 4           U
# ..        ...
# 95          U
# 96       None
# 97       None
# 98       None
# 99       None
#
# [100 rows x 6 columns]

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Write Your Code here
production_country = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    country = tags.find('h3', class_="detail-infos__subheading", string=" Production country ").find_next('div', class_="detail-infos__value").text.strip()
    production_country.append(country)

# pd.DataFrame(production_country)
# tv_dict['country'] = production_country
# pd.DataFrame(tv_dict)

# %%
tv_dict['country'] = production_country
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title release_year  \
# 0                          Reacher       (2022)
# 1                   True Detective       (2014)
# 2              Indian Police Force       (2024)
# 3                         Mirzapur       (2018)
# 4                  Game of Thrones       (2011)
# ..                             ...          ...
# 95             The Big Bang Theory       (2007)
# 96                       The Flash       (2014)
# 97  Alexander: The Making of a God       (2024)
# 98       The King: Eternal Monarch       (2020)
# 99      The Trust: A Game of Greed       (2024)
#
#                                                 genre     imdb_rating  \
# 0   Action & Adventure, Crime, Drama, Mystery & Th...     8.1  (195k)
# 1                    Drama, Mystery & Thriller, Crime     8.9  (632k)
# 2                           Action & Adventure, Crime      5.8  (50k)
# 3   Crime, Action & Adventure, Drama, Mystery & Th...      8.5  (80k)
# 4   Drama, Action & Adventure, Science-Fiction, Fa...       9.2  (2m)
# ..                                                ...             ...
# 95                                    Comedy, Romance     8.2  (857k)
# 96         Action & Adventure, Drama, Science-Fiction     7.5  (366k)
# 97                        Documentary, Drama, History       5.1  (2k)
# 98                             Drama, Science-Fiction  Baek Sang-Hoon
# 99                                         Reality TV             6.2
#
#    age_rating         country
# 0           A   United States
# 1           U   United States
# 2           A           India
# 3        None           India
# 4           U   United States
# ..        ...             ...
# 95          U   United States
# 96       None   United States
# 97       None  United Kingdom
# 98       None     South Korea
# 99       None   United States
#
# [100 rows x 7 columns]

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Write Your Code here
streaming_service = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    platform = tags.find('h2', class_="heading").find_next('p').text.strip()
    streaming_service.append(platform)

# pd.DataFrame(streaming_service)
# tv_dict['streaming_service'] = streaming_service
# pd.DataFrame(tv_dict)

# %%
tv_dict['streaming_service'] = streaming_service
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title release_year  \
# 0                          Reacher       (2022)
# 1                   True Detective       (2014)
# 2              Indian Police Force       (2024)
# 3                         Mirzapur       (2018)
# 4                  Game of Thrones       (2011)
# ..                             ...          ...
# 95             The Big Bang Theory       (2007)
# 96                       The Flash       (2014)
# 97  Alexander: The Making of a God       (2024)
# 98       The King: Eternal Monarch       (2020)
# 99      The Trust: A Game of Greed       (2024)
#
#                                                 genre     imdb_rating  \
# 0   Action & Adventure, Crime, Drama, Mystery & Th...     8.1  (195k)
# 1                    Drama, Mystery & Thriller, Crime     8.9  (632k)
# 2                           Action & Adventure, Crime      5.8  (50k)
# 3   Crime, Action & Adventure, Drama, Mystery & Th...      8.5  (80k)
# 4   Drama, Action & Adventure, Science-Fiction, Fa...       9.2  (2m)
# ..                                                ...             ...
# 95                                    Comedy, Romance     8.2  (857k)
# 96         Action & Adventure, Drama, Science-Fiction     7.5  (366k)
# 97                        Documentary, Drama, History       5.1  (2k)
# 98                             Drama, Science-Fiction  Baek Sang-Hoon
# 99                                         Reality TV             6.2
#
#    age_rating         country  \
# 0           A   United States
# 1           U   United States
# 2           A           India
# 3        None           India
# 4           U   United States
# ..        ...             ...
# 95          U   United States
# 96       None   United States
# 97       None  United Kingdom
# 98       None     South Korea
# 99       None   United States
#
#                                     streaming_service
# 0   Currently you are able to watch "Reacher" stre...
# 1   Currently you are able to watch "True Detectiv...
# 2   Currently you are able to watch "Indian Police...
# 3   Currently you are able to watch "Mirzapur" str...
# 4   Currently you are able to watch "Game of Thron...
# ..                                                ...
# 95  Currently you are able to watch "The Big Bang ...
# 96  We try to add new providers constantly but we ...
# 97  Currently you are able to watch "Alexander: Th...
# 98  Currently you are able to watch "The King: Ete...
# 99  Currently you are able to watch "The Trust: A ...
#
# [100 rows x 8 columns]

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Write Your Code here
movie_duration = []
for link in tv_show_links:
    response = requests.get(link)
    tags = BeautifulSoup(response.content, "html.parser")

    # Extract the required data from the page and append it to list
    duration = tags.find('h3', class_="detail-infos__subheading", string="Runtime").find_next('div', class_="detail-infos__value").text.strip()
    movie_duration.append(duration)

# pd.DataFrame(movie_duration)
# tv_dict['duration'] = movie_duration
# pd.DataFrame(tv_dict)

# %%
tv_dict['duration'] = movie_duration
pd.DataFrame(tv_dict)
# Out:
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                              title release_year  \
# 0                          Reacher       (2022)
# 1                   True Detective       (2014)
# 2              Indian Police Force       (2024)
# 3                         Mirzapur       (2018)
# 4                  Game of Thrones       (2011)
# ..                             ...          ...
# 95             The Big Bang Theory       (2007)
# 96                       The Flash       (2014)
# 97  Alexander: The Making of a God       (2024)
# 98       The King: Eternal Monarch       (2020)
# 99      The Trust: A Game of Greed       (2024)
#
#                                                 genre     imdb_rating  \
# 0   Action & Adventure, Crime, Drama, Mystery & Th...     8.1  (195k)
# 1                    Drama, Mystery & Thriller, Crime     8.9  (632k)
# 2                           Action & Adventure, Crime      5.8  (50k)
# 3   Crime, Action & Adventure, Drama, Mystery & Th...      8.5  (80k)
# 4   Drama, Action & Adventure, Science-Fiction, Fa...       9.2  (2m)
# ..                                                ...             ...
# 95                                    Comedy, Romance     8.2  (857k)
# 96         Action & Adventure, Drama, Science-Fiction     7.5  (366k)
# 97                        Documentary, Drama, History       5.1  (2k)
# 98                             Drama, Science-Fiction  Baek Sang-Hoon
# 99                                         Reality TV             6.2
#
#    age_rating         country  \
# 0           A   United States
# 1           U   United States
# 2           A           India
# 3        None           India
# 4           U   United States
# ..        ...             ...
# 95          U   United States
# 96       None   United States
# 97       None  United Kingdom
# 98       None     South Korea
# 99       None   United States
#
#                                     streaming_service  duration
# 0   Currently you are able to watch "Reacher" stre...     48min
# 1   Currently you are able to watch "True Detectiv...     59min
# 2   Currently you are able to watch "Indian Police...     38min
# 3   Currently you are able to watch "Mirzapur" str...     50min
# 4   Currently you are able to watch "Game of Thron...     58min
# ..                                                ...       ...
# 95  Currently you are able to watch "The Big Bang ...     20min
# 96  We try to add new providers constantly but we ...     42min
# 97  Currently you are able to watch "Alexander: Th...     39min
# 98  Currently you are able to watch "The King: Ete...  1h 12min
# 99  Currently you are able to watch "The Trust: A ...     52min
#
# [100 rows x 9 columns]

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Write Your Code here
pd.DataFrame(tv_dict, columns=['title', 'release_year', 'duration', 'imdb_rating', 'age_rating', 'country', 'genre', 'link', 'streaming_service'])
# Out:
#                              title release_year  duration     imdb_rating  \
# 0                          Reacher       (2022)     48min     8.1  (195k)
# 1                   True Detective       (2014)     59min     8.9  (632k)
# 2              Indian Police Force       (2024)     38min      5.8  (50k)
# 3                         Mirzapur       (2018)     50min      8.5  (80k)
# 4                  Game of Thrones       (2011)     58min       9.2  (2m)
# ..                             ...          ...       ...             ...
# 95             The Big Bang Theory       (2007)     20min     8.2  (857k)
# 96                       The Flash       (2014)     42min     7.5  (366k)
# 97  Alexander: The Making of a God       (2024)     39min       5.1  (2k)
# 98       The King: Eternal Monarch       (2020)  1h 12min  Baek Sang-Hoon
# 99      The Trust: A Game of Greed       (2024)     52min             6.2
#
#    age_rating         country  \
# 0           A   United States
# 1           U   United States
# 2           A           India
# 3        None           India
# 4           U   United States
# ..        ...             ...
# 95          U   United States
# 96       None   United States
# 97       None  United Kingdom
# 98       None     South Korea
# 99       None   United States
#
#                                                 genre  \
# 0   Action & Adventure, Crime, Drama, Mystery & Th...
# 1                    Drama, Mystery & Thriller, Crime
# 2                           Action & Adventure, Crime
# 3   Crime, Action & Adventure, Drama, Mystery & Th...
# 4   Drama, Action & Adventure, Science-Fiction, Fa...
# ..                                                ...
# 95                                    Comedy, Romance
# 96         Action & Adventure, Drama, Science-Fiction
# 97                        Documentary, Drama, History
# 98                             Drama, Science-Fiction
# 99                                         Reality TV
#
#                                                  link  \
# 0   https://www.justwatch.com/in/tv-show/jack-reacher
# 1   https://www.justwatch.com/in/tv-show/true-dete...
# 2   https://www.justwatch.com/in/tv-show/indian-po...
# 3       https://www.justwatch.com/in/tv-show/mirzapur
# 4   https://www.justwatch.com/in/tv-show/game-of-t...
# ..                                                ...
# 95  https://www.justwatch.com/in/tv-show/the-big-b...
# 96     https://www.justwatch.com/in/tv-show/the-flash
# 97  https://www.justwatch.com/in/tv-show/alexander...
# 98  https://www.justwatch.com/in/tv-show/the-king-...
# 99  https://www.justwatch.com/in/tv-show/the-trust...
#
#                                     streaming_service
# 0   Currently you are able to watch "Reacher" stre...
# 1   Currently you are able to watch "True Detectiv...
# 2   Currently you are able to watch "Indian Police...
# 3   Currently you are able to watch "Mirzapur" str...
# 4   Currently you are able to watch "Game of Thron...
# ..                                                ...
# 95  Currently you are able to watch "The Big Bang ...
# 96  We try to add new providers constantly but we ...
# 97  Currently you are able to watch "Alexander: Th...
# 98  Currently you are able to watch "The King: Ete...
# 99  Currently you are able to watch "The Trust: A ...
#
# [100 rows x 9 columns]

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %%
# Write Your Code here

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
# Write Your Code here

# %% [markdown]
# ## **Analyzing Top Genres**

# %%
# Write Your Code here

# %%
#Let's Visvalize it using word cloud

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
# Write Your Code here

# %%
#Let's Visvalize it using word cloud

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#saving final dataframe as Final Data in csv format

# %%
#saving filter data as Filter Data in csv format

# %% [markdown]
# # **Dataset Drive Link (View Access with Anyone) -**

# %% [markdown]
# # ***Congratulations!!! You have completed your Assignment.***
